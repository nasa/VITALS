# %% [markdown]
# # Use Case Land Cover Dangermond
#
# This notebook is just a placeholder with some basic opening/plotting for now. There is a time-series example here: https://nasa-openscapes.github.io/2021-Cloud-Hackathon/tutorials/05_Data_Access_Direct_S3.html that we could use as an example.

# %%
# Import Packages
import os
import glob
import math
import earthaccess
import numpy as np
import pandas as pd
import xarray as xr
from osgeo import gdal
import rasterio as rio
import rioxarray as rxr
import hvplot.xarray
import hvplot.pandas
import holoviews as hv
import geoviews as gv
import geopandas as gp
import sys
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>

# %% [markdown]
# Could still do better with identifying paired scenes.

# %%
ewt_file_list = [f for f in os.listdir('../../shared/2023-VITALS-Workshop-AGU/data/cropped/dangermond/ewt/') if '.tif' in f]
lst_file_list = [f for f in os.listdir('../../shared/2023-VITALS-Workshop-AGU/data/cropped/dangermond/lst/') if '.tif' in f]

# %%
ewt_file_list
# Out:
# ['EMIT_L2A_RFL_001_20230401T203751_2309114_002_dangermond_cwc.tif',
#  'EMIT_L2A_RFL_001_20230219T202939_2305013_002_dangermond_cwc.tif',
#  'EMIT_L2A_RFL_001_20230422T195924_2311213_002_dangermond_cwc.tif',
#  'EMIT_L2A_RFL_001_20230405T190311_2309513_002_dangermond_cwc.tif',
#  'EMIT_L2A_RFL_001_20231014T224006_2328715_002_dangermond_cwc.tif',
#  'EMIT_L2A_RFL_001_20230923T232101_2326615_002_dangermond_cwc.tif',
#  'EMIT_L2A_RFL_001_20230219T202951_2305013_003_dangermond_cwc.tif',
#  'EMIT_L2A_RFL_001_20230219T202939_2305013_002_dangermond_cwc_merged.tif',
#  'EMIT_L2A_RFL_001_20230629T170449_2318011_002_dangermond_cwc.tif']

# %%
lst_file_list
# Out:
# ['ECOv002_L2T_LSTE_26921_001_10SGD_20230405T190258_0710_01_LST_dangermond.tif',
#  'ECOv002_L2T_LSTE_29901_007_10SGD_20231014T223936_0711_01_LST_dangermond.tif',
#  'ECOv002_L2T_LSTE_29576_005_10SGD_20230923T232104_0710_01_LST_dangermond.tif',
#  'ECOv002_L2T_LSTE_28238_012_10SGD_20230629T170416_0710_01_LST_dangermond.tif',
#  'ECOv002_L2T_LSTE_26860_001_10SGD_20230401T203733_0710_01_LST_dangermond.tif',
#  'ECOv002_L2T_LSTE_26223_012_10SGD_20230219T202943_0710_01_LST_dangermond.tif']

# %% [markdown]
# There are more EWT because an ecostress scene is empty for one of the dates, and two ewt scenes needed to be merged. The Create a time index based on filenames
